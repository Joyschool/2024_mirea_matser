# %% [markdown]
# ## 웹크롤링 - BeautifulSoup
# (Visual Studio Code에서 실행)

# %% [markdown]
# - 공식페이지 : https://www.crummy.com/software/BeautifulSoup/
# - 참고 : https://wikidocs.net/198942

# %% [markdown]
# ### 1.라이브러리 설치

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\python\python310\lib\site-packages (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python\python310\lib\site-packages (from requests) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\python\python310\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python\python310\lib\site-packages (from requests) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\python310\lib\site-packages (from requests) (2021.10.8)

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\python\python310\lib\site-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in c:\python\python310\lib\site-packages (from beautifulsoup4) (2.3.2.post1)

# %%
import bs4 
bs4.__version__
# Out:
# '4.11.2'

# %% [markdown]
# ### 2.BeautifulSoup 사용

# %% [markdown]
# #### [예제] Text 제목 정보 1개 가져오기 in (정적인 페이지)

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://search.naver.com/search.naver?where=view&sm=tab_jum&query=10%EC%9B%94+%EC%A0%9C%EC%A3%BC'
print(url)

response = requests.get(url)

if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    title = soup.select_one('#main_pack > section > more-contents > div > ul > li:nth-child(1) > div > div.detail_box > div.title_area > a')
    print(title)
    print(title.get_text())
else : 
    print(response.status_code)
print('----------')
# Out:
# https://search.naver.com/search.naver?where=view&sm=tab_jum&query=10%EC%9B%94+%EC%A0%9C%EC%A3%BC
# <a class="title_link _cross_trigger" data-cr-gdid="90000003_0000000000000033F92070A2" href="https://blog.naver.com/kayak71/223222984866" onclick="return goOtherCR(this, 'a=rvw*w.link&amp;r=1&amp;i=90000003_0000000000000033F92070A2&amp;u='+urlencode(this.href))" target="_blank"><mark>10월 제주</mark>도 가볼만한곳 : 제주 서귀포 치유의 숲 예약</a>
# 10월 제주도 가볼만한곳 : 제주 서귀포 치유의 숲 예약
# ----------

# %% [markdown]
# #### [예제] Text 정보 여러 개 가져오기 in (정적인 페이지)

# %%
import requests
from bs4 import BeautifulSoup

print('페이지 정보 추출하기-----')
url = 'https://search.naver.com/search.naver?where=view&sm=tab_jum&query=10%EC%9B%94+%EC%A0%9C%EC%A3%BC'
print(url)

response = requests.get(url)

t_list, d_list, link_list = [], [], []
if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    ul = soup.select_one('ul.lst_view._list_base') #공백에 있을 경우 . 사용
    # 제목, 링크
    titles = ul.select('li > div > div > div.title_area > a')
    for title in titles: 
        t_list.append(title.get_text())
        link_list.append(title.attrs['href'])
#         print(title.get_text())        
    # 상세 설명
    titles = ul.select('li > div > div > div.dsc_area > a')
    for title in titles: 
        d_list.append(title.get_text())  
else : 
    print(response.status_code)
print('페이지 정보 추출완료-----')
t_list, d_list, link_list
# Out:
# 페이지 정보 추출하기-----
# https://search.naver.com/search.naver?where=view&sm=tab_jum&query=10%EC%9B%94+%EC%A0%9C%EC%A3%BC
# 페이지 정보 추출완료-----
# (['10월 제주도 가볼만한곳 : 제주 서귀포 치유의 숲 예약',
#   '제주여행 제주동쪽 10월 가볼만한곳 명소 풍경들',
#   '10월 제주도 여행지 추천 제주 표선 가볼만한곳 제주민속촌 입장료',
#   '10월 제주도 여행 제주 산굼부리 억새 제주도 명소 추천 코스',
#   '10월 제주여행 꽃 구경 할만한 제주도 핑크뮬리 카페 마노르블랑',
#   '10월 제주여행 인생사진찍기좋은곳 휴애리 핑크뮬리 제주도 숨은명소',
#   '제주 해바라기 축제 명소 제주도 10월 가을 축제',
#   '10월 제주여행 2박 3일 추천 코스',
#   '10월 제주여행 김포공항 국내선 탑승기',
#   '10월 제주도 여행 추천 제주 여행 코스',
#   '10월 제주도 여행 제주 오라동 메밀밭 메밀꽃 포토존',
#   '10월 제주 가볼 만한 곳 이색 볼거리 가득한 제26회 제주 탐라문화제',
#   '[10월 제주여행]숙소_그랜드하얏트 제주',
#   '가을 제주 단풍명소 10월 중순부터 11월 말까지 저는 여기 다녀와요',
#   '[10월 제주] 제주돌문화공원',
#   '10월 제주 가을여행 휴애리 자연생활공원 제주도 핑크뮬리 축제',
#   '10월 제주도 여행 제주 핑크뮬리 명소 가볼만한곳 새미동산',
#   '10월 제주여행 카페 글렌코 제주도 핑크뮬리 시기 옷차림 날씨',
#   '제주도 억새 명소 어음리억새군락지 제주 서쪽 아이랑 10월 11월',
#   '10월 중순 제주',
#   '10월 제주도 서핑 가능할까요?',
#   '9월 10월 제주 가볼만한곳 한적한 여행코스 서부농업기술센터',
#   '10월 가볼만한곳 제주도 억새 새별오름 제주 서쪽 오름',
#   '제주도 가을여행, 10월 제주 가볼만한곳 BEST 5 추천!',
#   '10월 제주는 억새와 핑크뮬리 천지 ~',
#   '10월 제주도 여행 제주시 가볼만한곳 제주공항 근처 관광지 볼거리',
#   '제주공항근처 가볼만한곳 관광지 10월 11월 제주도 여행',
#   '10월 야놀자 제주 항공권 최대 12만원 할인받기',
#   '10월 여행지 제주 새별 오름 제주도 억새 서쪽 오름 가을 나들이',
#   '10월 제주도 핑크뮬리 축제 여행 제주 마노르블랑 카페 산방산 뷰'],
#  ['돌아가는길 10월 제주도 가볼만한곳 서귀포 치유의숲 오르는길 흐렸다면 돌아갈때는 맑아 같은 장소에 있는 제주도 숲 이지만 다가오는 느낌은 달랐는데요 흑백 TV 에서 LCD TV 로 넘어간듯한 화질 입니다 좀더 푸르러진 제주 가볼만한곳 치유의숲 으로 다리 풀려 완만한...',
#   '풍경도 아름답다 하니 10월 해 질 무렵 찾아가면 노을빛에 물든 황홀한 은빛 물결 볼 수 있을 거예요. 10월에 아쿠아플라넷 제주를 비롯한 제주 동쪽 명소를 찾으면 아름다운 제주도 여행 추억 간직할 수 있을 거예요. #제주여행 #제주동쪽 #제주10월여행 #제주10월가볼만한곳',
#   '대표적인 제주 표선 가볼만한곳으로 10월 제주도 여행지로도 추천하는 곳입니다. 가을 나들이 삼아 찾기에 좋아 보였어요. #제주도표선 #제주표선가볼만한곳 #제주민속촌 #10월제주도여행 #제주도여행 #제주도여행지 #10월여행지 #제주도여행지추천 #여행지추천',
#   '10월 제주도 여행 제주 산굼부리 억세 제주도 명소 추천 코스 글, 사진 : 그루터기 제주도 억새를 보기 위해 가장 많이 찾는 여행지 중 한 곳은 제주도 산굼부리다. 새별 오름을 비롯한 오름도 억새가 멋지지만 오르는 코스가 쉽지 않은 반면 제주 산굼부리는 비탈길을 따라...',
#   '10월 가볼만한곳 제주도 억새 새별오름 제주 서쪽 오름 동영상 10월 제주도 가볼만한곳 : 핑크뮬리 카페 마노르블랑 & Korea Tour :: 10월 가볼만한곳 제주 새별오름 정리 지금부터 제주 새별오름은 11월까지 억새가 무성하게 피어 있습니다. 제주 서쪽 오름 중 조망이 아름답고...',
#   '날씨가 선선해져서 푸른 바다나 오름을 돌아다니기도 더욱 편리해지죠.오늘은 억새를 중심으로\xa010월 제주도 가을여행 가볼만한곳 5곳을 추천해 드릴게요. 눈부신 자연과 함께 제주의 가을을 즐겨보세요!\xa0 \xa0 \xa0\xa0 제주도 가을여행 가볼만한곳 추천 5곳! 1. 산굼부리2....',
#   '가을에 제주에 가신다면 억새와 핑크뮬리 보셔요~ 명불허전 새별오름~ 요건 9월말 사진인데 해마다 차이는 있어도 보통 10월초~중순전에 억새가 제일 싱싱합니다. (지역별 차이 ○) 오르실때는 경사가 완만한 오른쪽으로 올라가세요~ 억새철에 가볼만한 정물오름~ 오른쪽은...',
#   '텐데요.10월 제주도 가볼만한곳 여행 준비하는 분들께 여행지 소식 전해드려요. 기상청에 따르면 제주 한라산 단풍 절정시기는 10월... ::10월 제주도 가볼만한곳 제주시 가볼만한곳 6 :: ✓ 몰입형 미디어아트 제주도 가볼만한곳 실내 전시 노형수퍼마켙 ✓ 아이스뮤지엄과...',
#   '제주공항근처 가볼만한곳 10월 11월 제주도 여행 글/사진/영상 춤추는 쥬디 9월과 10월 연달아 제주도 여행을 다녀온 여행작가 쥬디입니다. 서울은 아침저녁으로 날이 쌀쌀해졌는데 제주는 아직 날씨가 포근해서 가을여행하기 정말 좋더라고요. 10월 초에 제주도 갔을 때 날씨...',
#   '야놀자 X 제주여행 10월 특가 제주 항공권 숙소 렌터카 레저 할인팁 글 | 사진 세지쓰 - 올 가을은 어디에서 행복할 거에요? 계절마다... 야놀자 제주도 숙소 10-월 할인 쿠폰팩 이용해서 다시 한번 방문해보고 싶네요. 3. 제주 렌터카 10월 제주 렌터카 최대 5천원 할인쿠폰...',
#   '지금쯤 간다면 그 때보다 더 은빛 이삭을 활짝 펼치고 있을텐데요. 가을 나들이로 추천하는 제주도 오름이에요. #10월여행지 #제주새별오름 #제주도새별오름 #제주도억새 #제주도오름 #제주오름 #제주서쪽 #제주도서쪽 #새별오름 #제주도서쪽오름 #가을나들이',
#   '제주도 억새 시즌 제주도 핑크뮬리와 함께 즐겨줘야 할 가을 제주도 억새! 가장 좋아하는 산굼부리는 산책하기도 좋았고 바람에 흔들리는 황금물결이 장관 그 자체였던 곳이라 지금 10월 제주도 여행을 떠난다면 꼭 들러봐야 할 곳이 아닌가 싶어요 3. 제주 핑크뮬리 카페...'],
#  ['https://blog.naver.com/kayak71/223222984866',
#   'https://blog.naver.com/ka8564/223230868738',
#   'https://blog.naver.com/overroad89/223224371702',
#   'https://blog.naver.com/hloveh01/223241505536',
#   'https://blog.naver.com/grandtheft3/223224941585',
#   'https://blog.naver.com/h100489/223231967760',
#   'https://blog.naver.com/fabrunch/223233646956',
#   'https://blog.naver.com/coolestlove/223225600726',
#   'https://perfume700.tistory.com/5437',
#   'https://blog.naver.com/hnmh2332/223225151538',
#   'https://blog.naver.com/pure_quf/223248246395',
#   'https://blog.naver.com/risingyou21/223230462968',
#   'https://blog.naver.com/gasyyeon/223243532234',
#   'https://blog.naver.com/hhome1/223241218816',
#   'https://blog.naver.com/tree824/223245245296',
#   'https://blog.naver.com/zltm31/223220583039',
#   'https://blog.naver.com/80sunjin/223232069107',
#   'https://blog.naver.com/daisy1505/223220023402',
#   'https://blog.naver.com/gftravel/223245500286',
#   'https://cafe.naver.com/jejutip/2339832?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImplanV0aXAiLCJhcnRpY2xlSWQiOjIzMzk4MzIsImlzc3VlZEF0IjoxNjk4ODE0MDU4MjkwfQ.N83HR_Yuv11HllZmSMLobdAgMrGF2zTu5fSCel5e_fs',
#   'https://cafe.naver.com/hyjnavercom/187282?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6Imh5am5hdmVyY29tIiwiYXJ0aWNsZUlkIjoxODcyODIsImlzc3VlZEF0IjoxNjk4ODE0MDU4MjkxfQ.GjCeARaj-WL2tTZdcN8_bgolyTE8wjUr847KvccYwQU',
#   'https://blog.naver.com/qkrgkdms1993/223199228675',
#   'https://blog.naver.com/g0heaven/223222731196',
#   'https://post.naver.com/viewer/postView.naver?volumeNo=36505890&memberNo=8591454&vType=VERTICAL',
#   'https://cafe.naver.com/jejutip/2348159?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImplanV0aXAiLCJhcnRpY2xlSWQiOjIzNDgxNTksImlzc3VlZEF0IjoxNjk4ODE0MDU4MjkzfQ.8_zFMC4SsLYlNaImfJ3osNmULFXzvKHgu_7nuYEf1vo',
#   'https://blog.naver.com/neweunha/223244388096',
#   'https://blog.naver.com/1ove_honesty/223239079592',
#   'https://blog.naver.com/forceofwill/223242004548',
#   'https://blog.naver.com/jbm993/223243729307',
#   'https://blog.naver.com/bahna2/223235546628'])

# %%
import pandas as pd

data = {'title': t_list, 'desc':d_list,'link':link_list}
df = pd.DataFrame(data)
df
# Out:
#                                       title  \
# 0           10월 제주도 가볼만한곳 : 제주 서귀포 치유의 숲 예약
# 1                제주여행 제주동쪽 10월 가볼만한곳 명소 풍경들
# 2      10월 제주도 여행지 추천 제주 표선 가볼만한곳 제주민속촌 입장료
# 3        10월 제주도 여행 제주 산굼부리 억새 제주도 명소 추천 코스
# 4       10월 제주여행 꽃 구경 할만한 제주도 핑크뮬리 카페 마노르블랑
# 5      10월 제주여행 인생사진찍기좋은곳 휴애리 핑크뮬리 제주도 숨은명소
# 6               제주 해바라기 축제 명소 제주도 10월 가을 축제
# 7                      10월 제주여행 2박 3일 추천 코스
# 8                     10월 제주여행 김포공항 국내선 탑승기
# 9                    10월 제주도 여행 추천 제주 여행 코스
# 10            10월 제주도 여행 제주 오라동 메밀밭 메밀꽃 포토존
# 11  10월 제주 가볼 만한 곳 이색 볼거리 가득한 제26회 제주 탐라문화제
# 12                   [10월 제주여행]숙소_그랜드하얏트 제주
# 13   가을 제주 단풍명소 10월 중순부터 11월 말까지 저는 여기 다녀와요
