# %% [markdown]
# ## 웹크롤링 - BeautifulSoup

# %% [markdown]
# - 공식페이지 : https://www.crummy.com/software/BeautifulSoup/
# - 참고 : https://wikidocs.net/198942

# %% [markdown]
# ### 1.라이브러리 설치

# %%
# !pip install beautifulsoup4

# %%
import bs4 
bs4.__version__
# Out:
# '4.11.2'

# %% [markdown]
# ### 2.BeautifulSoup 사용

# %% [markdown]
# #### [예제] Text 제목 정보 1개 가져오기 in (정적인 페이지)

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://search.naver.com/search.naver?where=view&sm=tab_jum&query=10%EC%9B%94+%EC%A0%9C%EC%A3%BC'
print(url)

response = requests.get(url)

if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    title = soup.select_one('#main_pack > section > more-contents > div > ul > li:nth-child(1) > div > div.detail_box > div.title_area > a')
    print(title)
    print(title.get_text())
else : 
    print(response.status_code)
print('----------')

# %% [markdown]
# #### [예제] Text 정보 여러 개 가져오기 in (정적인 페이지)

# %%
import requests
from bs4 import BeautifulSoup

print('페이지 정보 추출하기-----')
url = 'https://search.naver.com/search.naver?where=view&sm=tab_jum&query=10%EC%9B%94+%EC%A0%9C%EC%A3%BC'
print(url)

response = requests.get(url)

t_list, d_list, link_list = [], [], []
if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    ul = soup.select_one('ul.lst_view._list_base') #공백에 있을 경우 . 사용
    # 제목
    titles = ul.select('li > div > div > div.title_area > a')
    for title in titles: 
        t_list.append(title.get_text())
        link_list.append(title.attrs['href'])
#         print(title.get_text())        
    # 상세 설명
    titles = ul.select('li > div > div > div.dsc_area > a')
    for title in titles: 
        d_list.append(title.get_text())  
else : 
    print(response.status_code)
print('페이지 정보 추출완료-----')
# t_list, d_list, link_list
# Out:
# 페이지 정보 추출하기-----
# https://search.naver.com/search.naver?where=view&sm=tab_jum&query=10%EC%9B%94+%EC%A0%9C%EC%A3%BC
# 페이지 정보 추출완료-----

# %%
import pandas as pd

data = {'title': t_list, 'desc':d_list,'link':link_list}
df = pd.DataFrame(data)
df
# Out:
#                                                 title  \
# 0                     10월 제주도 가볼만한곳 : 제주 서귀포 치유의 숲 예약
# 1                10월 제주도 여행지 추천 제주 표선 가볼만한곳 제주민속촌 입장료
# 2                          제주여행 제주동쪽 10월 가볼만한곳 명소 풍경들
# 3                               10월 제주는 억새와 핑크뮬리 천지 ~
# 4                  10월 제주도 여행 제주 산굼부리 억새 제주도 명소 추천 코스
# 5                 10월 제주여행 꽃 구경 할만한 제주도 핑크뮬리 카페 마노르블랑
# 6                10월 제주여행 인생사진찍기좋은곳 휴애리 핑크뮬리 제주도 숨은명소
# 7                                           10월 중순 제주
# 8                         제주 해바라기 축제 명소 제주도 10월 가을 축제
# 9                                   10월 제주도 서핑 가능할까요?
# 10                               10월 제주여행 2박 3일 추천 코스
# 11                              10월 제주여행 김포공항 국내선 탑승기
# 12                             10월 제주도 여행 추천 제주 여행 코스
# 13            10월 제주 가볼 만한 곳 이색 볼거리 가득한 제26회 제주 탐라문화제
# 14                             [10월 제주여행]숙소_그랜드하얏트 제주
# 15                      10월 제주도 여행 제주 오라동 메밀밭 메밀꽃 포토존
